# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
topk_jeep_path = "..\\trained_gans\\projgan-topk-jeep\\"
topk_fish_path = "..\\trained_gans\\projgan-topk-fish\\"
regular_jeep_path = "..\\trained_gans\\projgan-regular-jeep\\"
regular_fish_path = "..\\trained_gans\\projgan-regular-fish\\"

# %%
topk_json = pd.read_json(path_or_buf=topk_jeep_path+"stats.jsonl", lines=True)
topk_json.head()
# Out:
#                                     Loss/scores/fake  \
# 0  {'num': 12800, 'mean': -0.058390960395336006, ...
# 1  {'num': 102400, 'mean': -2.046276194751263, 's...
# 2  {'num': 102400, 'mean': -2.399820394515991, 's...
# 3  {'num': 102400, 'mean': -2.446077024936676, 's...
# 4  {'num': 102400, 'mean': -2.527854410409927, 's...
#
#                                      Loss/signs/fake  \
# 0  {'num': 12800, 'mean': -0.04984375, 'std': 0.9...
# 1  {'num': 102400, 'mean': -0.7203125, 'std': 0.6...
# 2  {'num': 102400, 'mean': -0.8580273437499999, '...
# 3  {'num': 102400, 'mean': -0.8830078125, 'std': ...
# 4  {'num': 102400, 'mean': -0.8885351562499999, '...
#
#                                          Loss/G/loss  \
# 0  {'num': 8, 'mean': 0.059918279526755006, 'std'...
# 1  {'num': 64, 'mean': 2.172486781142652, 'std': ...
# 2  {'num': 64, 'mean': 2.525395641103387, 'std': ...
# 3  {'num': 64, 'mean': 2.569432603195309, 'std': ...
# 4  {'num': 64, 'mean': 2.613328063860535, 'std': ...
#
#                                     Loss/scores/real  \
# 0  {'num': 6400, 'mean': 0.060948173999786005, 's...
# 1  {'num': 51200, 'mean': 1.838058362007141, 'std...
# 2  {'num': 51200, 'mean': 2.293944752216339, 'std...
# 3  {'num': 51200, 'mean': 2.495986995697021, 'std...
# 4  {'num': 51200, 'mean': 2.504022870063782, 'std...
#
#                                      Loss/signs/real  \
# 0  {'num': 6400, 'mean': 0.0721875, 'std': 0.9973...
# 1  {'num': 51200, 'mean': 0.6382421875000001, 'st...
# 2  {'num': 51200, 'mean': 0.8324218750000001, 'st...
# 3  {'num': 51200, 'mean': 0.8732421875, 'std': 0....
# 4  {'num': 51200, 'mean': 0.85109375, 'std': 0.52...
#
#                                          Loss/D/loss  \
# 0  {'num': 8, 'mean': 1.940462991595268, 'std': 0...
# 1  {'num': 64, 'mean': 0.850851097377017, 'std': ...
# 2  {'num': 64, 'mean': 0.422224304638803, 'std': ...
# 3  {'num': 64, 'mean': 0.36059607216157, 'std': 0...
# 4  {'num': 64, 'mean': 0.37890200014226105, 'std'...
#
#                          Progress/tick  \
# 0  {'num': 1, 'mean': 0.0, 'std': 0.0}
# 1  {'num': 1, 'mean': 1.0, 'std': 0.0}
# 2  {'num': 1, 'mean': 2.0, 'std': 0.0}
# 3  {'num': 1, 'mean': 3.0, 'std': 0.0}
# 4  {'num': 1, 'mean': 4.0, 'std': 0.0}
#
#                                        Progress/kimg  \
# 0  {'num': 1, 'mean': 0.06400000303983601, 'std':...
# 1  {'num': 1, 'mean': 0.575999975204467, 'std': 0.0}
# 2  {'num': 1, 'mean': 1.088000059127807, 'std': 0.0}
# 3  {'num': 1, 'mean': 1.600000023841858, 'std': 0.0}
# 4  {'num': 1, 'mean': 2.111999988555908, 'std': 0.0}
#
#                                     Timing/total_sec  \
# 0  {'num': 1, 'mean': 54.23356628417969, 'std': 0.0}
# 1  {'num': 1, 'mean': 115.80668640136719, 'std': ...
# 2  {'num': 1, 'mean': 172.7024688720703, 'std': 0.0}
# 3  {'num': 1, 'mean': 229.50167846679688, 'std': ...
# 4  {'num': 1, 'mean': 286.31219482421875, 'std': ...
#
#                                  Timing/sec_per_tick  ...  \
# 0  {'num': 1, 'mean': 23.08785057067871, 'std': 0.0}  ...
# 1  {'num': 1, 'mean': 56.99003982543945, 'std': 0.0}  ...
# 2  {'num': 1, 'mean': 56.87095642089844, 'std': 0.0}  ...
# 3  {'num': 1, 'mean': 56.78871154785156, 'std': 0.0}  ...
# 4  {'num': 1, 'mean': 56.77937316894531, 'std': 0.0}  ...
#
#                               Timing/maintenance_sec  \
# 0  {'num': 1, 'mean': 31.145713806152344, 'std': ...
# 1  {'num': 1, 'mean': 4.583083152770996, 'std': 0.0}
# 2  {'num': 1, 'mean': 0.024826526641845002, 'std'...
# 3  {'num': 1, 'mean': 0.010493993759155001, 'std'...
# 4  {'num': 1, 'mean': 0.031145572662353002, 'std'...
#
#                                 Resources/cpu_mem_gb  \
# 0  {'num': 1, 'mean': 2.269920349121093, 'std': 0.0}
# 1  {'num': 1, 'mean': 2.366607666015625, 'std': 0.0}
# 2  {'num': 1, 'mean': 2.366622924804687, 'std': 0.0}
# 3  {'num': 1, 'mean': 2.366661071777343, 'std': 0.0}
# 4  {'num': 1, 'mean': 2.366664886474609, 'std': 0.0}
#
#                            Resources/peak_gpu_mem_gb  \
# 0  {'num': 1, 'mean': 11.12153434753418, 'std': 0.0}
# 1  {'num': 1, 'mean': 7.440924167633057, 'std': 0.0}
# 2    {'num': 1, 'mean': 7.4378342628479, 'std': 0.0}
# 3  {'num': 1, 'mean': 7.438595294952393, 'std': 0.0}
# 4  {'num': 1, 'mean': 7.441258430480957, 'std': 0.0}
#
#              Resources/peak_gpu_mem_reserved_gb  \
# 0   {'num': 1, 'mean': 12.57421875, 'std': 0.0}
# 1  {'num': 1, 'mean': 10.830078125, 'std': 0.0}
# 2  {'num': 1, 'mean': 10.830078125, 'std': 0.0}
# 3  {'num': 1, 'mean': 10.830078125, 'std': 0.0}
# 4  {'num': 1, 'mean': 10.830078125, 'std': 0.0}
#
#                                   Timing/total_hours  \
# 0  {'num': 1, 'mean': 0.015064879320561001, 'std'...
# 1  {'num': 1, 'mean': 0.032168522477149006, 'std'...
# 2  {'num': 1, 'mean': 0.047972910106182, 'std': 0.0}
# 3  {'num': 1, 'mean': 0.063750468194484, 'std': 0.0}
# 4  {'num': 1, 'mean': 0.079531162977218, 'std': 0.0}
#
#                                    Timing/total_days  \
# 0  {'num': 1, 'mean': 0.0006277033244250001, 'std...
# 1  {'num': 1, 'mean': 0.0013403551420190002, 'std...
# 2  {'num': 1, 'mean': 0.001998871099203, 'std': 0.0}
# 3  {'num': 1, 'mean': 0.0026562693528830003, 'std...
# 4  {'num': 1, 'mean': 0.003313798457384, 'std': 0.0}
#
#                                        Timing/Gboth  \
# 0    {'num': 1, 'mean': 20766.86328125, 'std': 0.0}
# 1  {'num': 1, 'mean': 4918.56005859375, 'std': 0.0}
# 2  {'num': 1, 'mean': 4892.24169921875, 'std': 0.0}
# 3     {'num': 1, 'mean': 4903.42578125, 'std': 0.0}
# 4  {'num': 1, 'mean': 4967.99072265625, 'std': 0.0}
#
#                                         Timing/Dmain  \
# 0   {'num': 1, 'mean': 2311.01318359375, 'std': 0.0}
# 1  {'num': 1, 'mean': 2184.016357421875, 'std': 0.0}
# 2  {'num': 1, 'mean': 2183.938720703125, 'std': 0.0}
# 3  {'num': 1, 'mean': 2167.654541015625, 'std': 0.0}
# 4  {'num': 1, 'mean': 2172.295654296875, 'std': 0.0}
#
#                                          Timing/Dreg  \
# 0  {'num': 1, 'mean': 0.002144000027328, 'std': 0.0}
# 1  {'num': 1, 'mean': 0.002144000027328, 'std': 0.0}
# 2  {'num': 1, 'mean': 0.002047999994829, 'std': 0.0}
# 3  {'num': 1, 'mean': 0.002047999994829, 'std': 0.0}
# 4  {'num': 1, 'mean': 0.002047999994829, 'std': 0.0}
#
#                       timestamp
# 0 2024-05-05 12:38:40.061961174
# 1 2024-05-05 12:39:37.077243090
# 2 2024-05-05 12:40:33.958356619
# 3 2024-05-05 12:41:30.778749943
# 4 2024-05-05 12:42:27.585113049
#
# [5 rows x 21 columns]

# %%
normal_json = pd.read_json(path_or_buf=regular_jeep_path+"stats.jsonl", lines=True)
normal_json.head()
# Out:
#                                     Loss/scores/fake  \
# 0  {'num': 12800, 'mean': -0.031493837088346, 'st...
# 1  {'num': 102400, 'mean': -1.594536450635641, 's...
# 2  {'num': 102400, 'mean': -1.9968565368652342, '...
# 3  {'num': 102400, 'mean': -2.179822181463241, 's...
# 4  {'num': 102400, 'mean': -2.064652144908905, 's...
#
#                                      Loss/signs/fake  \
# 0  {'num': 12800, 'mean': -0.031875, 'std': 0.999...
# 1  {'num': 102400, 'mean': -0.59216796875, 'std':...
# 2  {'num': 102400, 'mean': -0.81560546875, 'std':...
# 3  {'num': 102400, 'mean': -0.7996679687499999, '...
# 4  {'num': 102400, 'mean': -0.70216796875, 'std':...
#
#                                          Loss/G/loss  \
# 0  {'num': 8, 'mean': 0.040163527010008006, 'std'...
# 1  {'num': 64, 'mean': 1.793830114707816, 'std': ...
# 2  {'num': 64, 'mean': 2.106737492606044, 'std': ...
# 3  {'num': 64, 'mean': 2.34107656776905, 'std': 0...
# 4  {'num': 64, 'mean': 2.245680555701256, 'std': ...
#
#                                     Loss/scores/real  \
# 0  {'num': 6400, 'mean': 0.022269290536642002, 's...
# 1  {'num': 51200, 'mean': 1.377237629368901, 'std...
# 2  {'num': 51200, 'mean': 1.8171330535411832, 'st...
# 3  {'num': 51200, 'mean': 2.061324166059494, 'std...
# 4  {'num': 51200, 'mean': 1.826358022689819, 'std...
#
#                                      Loss/signs/real  \
# 0  {'num': 6400, 'mean': 0.060625, 'std': 0.99816...
# 1  {'num': 51200, 'mean': 0.5571875, 'std': 0.830...
# 2  {'num': 51200, 'mean': 0.7647265625, 'std': 0....
# 3  {'num': 51200, 'mean': 0.7670703125, 'std': 0....
# 4  {'num': 51200, 'mean': 0.6562890625000001, 'st...
#
#                                          Loss/D/loss  \
# 0  {'num': 8, 'mean': 1.996455192565918, 'std': 0...
# 1  {'num': 64, 'mean': 1.137054626829922, 'std': ...
# 2  {'num': 64, 'mean': 0.5516240154393011, 'std':...
# 3  {'num': 64, 'mean': 0.6083448806311931, 'std':...
# 4  {'num': 64, 'mean': 0.9008071599528191, 'std':...
#
#                          Progress/tick  \
# 0  {'num': 1, 'mean': 0.0, 'std': 0.0}
# 1  {'num': 1, 'mean': 1.0, 'std': 0.0}
# 2  {'num': 1, 'mean': 2.0, 'std': 0.0}
# 3  {'num': 1, 'mean': 3.0, 'std': 0.0}
# 4  {'num': 1, 'mean': 4.0, 'std': 0.0}
#
#                                        Progress/kimg  \
# 0  {'num': 1, 'mean': 0.06400000303983601, 'std':...
# 1  {'num': 1, 'mean': 0.575999975204467, 'std': 0.0}
# 2  {'num': 1, 'mean': 1.088000059127807, 'std': 0.0}
# 3  {'num': 1, 'mean': 1.600000023841858, 'std': 0.0}
# 4  {'num': 1, 'mean': 2.111999988555908, 'std': 0.0}
#
#                                     Timing/total_sec  \
# 0  {'num': 1, 'mean': 50.98099899291992, 'std': 0.0}
# 1  {'num': 1, 'mean': 113.4837875366211, 'std': 0.0}
# 2  {'num': 1, 'mean': 171.9483642578125, 'std': 0.0}
# 3  {'num': 1, 'mean': 230.90345764160156, 'std': ...
# 4  {'num': 1, 'mean': 289.6820068359375, 'std': 0.0}
#
#                                  Timing/sec_per_tick  ...  \
# 0  {'num': 1, 'mean': 23.727657318115234, 'std': ...  ...
# 1  {'num': 1, 'mean': 59.16503143310547, 'std': 0.0}  ...
# 2  {'num': 1, 'mean': 58.43049621582031, 'std': 0.0}  ...
# 3  {'num': 1, 'mean': 58.923858642578125, 'std': ...  ...
# 4  {'num': 1, 'mean': 58.74542236328125, 'std': 0.0}  ...
#
#                               Timing/maintenance_sec  \
# 0  {'num': 1, 'mean': 27.253339767456055, 'std': ...
# 1  {'num': 1, 'mean': 3.337754011154175, 'std': 0.0}
# 2  {'num': 1, 'mean': 0.034090995788574004, 'std'...
# 3  {'num': 1, 'mean': 0.031222581863403, 'std': 0.0}
# 4  {'num': 1, 'mean': 0.033125400543212, 'std': 0.0}
#
#                                 Resources/cpu_mem_gb  \
# 0  {'num': 1, 'mean': 2.205226898193359, 'std': 0.0}
# 1   {'num': 1, 'mean': 2.32086181640625, 'std': 0.0}
# 2  {'num': 1, 'mean': 2.320903778076172, 'std': 0.0}
# 3  {'num': 1, 'mean': 2.320926666259765, 'std': 0.0}
# 4  {'num': 1, 'mean': 2.3209304809570312, 'std': ...
#
#                            Resources/peak_gpu_mem_gb  \
# 0  {'num': 1, 'mean': 11.121562957763672, 'std': ...
# 1    {'num': 1, 'mean': 7.4316086769104, 'std': 0.0}
# 2  {'num': 1, 'mean': 7.430192470550537, 'std': 0.0}
# 3  {'num': 1, 'mean': 7.434365749359131, 'std': 0.0}
# 4  {'num': 1, 'mean': 7.430408000946045, 'std': 0.0}
#
#              Resources/peak_gpu_mem_reserved_gb  \
# 0   {'num': 1, 'mean': 12.30859375, 'std': 0.0}
# 1  {'num': 1, 'mean': 10.853515625, 'std': 0.0}
# 2  {'num': 1, 'mean': 10.853515625, 'std': 0.0}
# 3  {'num': 1, 'mean': 10.853515625, 'std': 0.0}
# 4  {'num': 1, 'mean': 10.853515625, 'std': 0.0}
#
#                                   Timing/total_hours  \
# 0  {'num': 1, 'mean': 0.014161388389766001, 'std'...
# 1  {'num': 1, 'mean': 0.031523272395133, 'std': 0.0}
# 2  {'num': 1, 'mean': 0.047763437032699, 'std': 0.0}
# 3  {'num': 1, 'mean': 0.064139850437641, 'std': 0.0}
# 4  {'num': 1, 'mean': 0.080467224121093, 'std': 0.0}
#
#                                    Timing/total_days  \
# 0  {'num': 1, 'mean': 0.000590057868976, 'std': 0.0}
# 1  {'num': 1, 'mean': 0.0013134697219350001, 'std...
# 2  {'num': 1, 'mean': 0.0019901432096950003, 'std...
# 3  {'num': 1, 'mean': 0.002672493690624, 'std': 0.0}
# 4  {'num': 1, 'mean': 0.0033528008498250003, 'std...
#
#                                        Timing/Gboth  \
# 0        {'num': 1, 'mean': 21353.9375, 'std': 0.0}
# 1  {'num': 1, 'mean': 5117.02490234375, 'std': 0.0}
# 2  {'num': 1, 'mean': 5099.99462890625, 'std': 0.0}
# 3   {'num': 1, 'mean': 5093.5439453125, 'std': 0.0}
# 4   {'num': 1, 'mean': 5093.2021484375, 'std': 0.0}
#
#                                         Timing/Dmain  \
# 0  {'num': 1, 'mean': 2361.473388671875, 'std': 0.0}
# 1   {'num': 1, 'mean': 2261.64111328125, 'std': 0.0}
# 2  {'num': 1, 'mean': 2257.158447265625, 'std': 0.0}
# 3  {'num': 1, 'mean': 2245.740478515625, 'std': 0.0}
# 4   {'num': 1, 'mean': 2248.47216796875, 'std': 0.0}
#
#                                          Timing/Dreg  \
# 0  {'num': 1, 'mean': 0.0030720001086590003, 'std...
# 1  {'num': 1, 'mean': 0.0030720001086590003, 'std...
# 2  {'num': 1, 'mean': 0.002047999994829, 'std': 0.0}
# 3  {'num': 1, 'mean': 0.002047999994829, 'std': 0.0}
# 4  {'num': 1, 'mean': 0.002240000059828, 'std': 0.0}
#
#                       timestamp
# 0 2024-04-20 18:12:45.875401735
# 1 2024-04-20 18:13:45.075010777
# 2 2024-04-20 18:14:43.536686897
# 3 2024-04-20 18:15:42.493571997
# 4 2024-04-20 18:16:41.267280102
#
# [5 rows x 21 columns]

# %%
normal_G_loss = [d.get('mean') for d in normal_json['Loss/G/loss']]
plt.plot(np.arange(0, len(normal_G_loss)/2, 0.5), normal_G_loss, label="Top-K")
topk_G_loss = [d.get('mean') for d in topk_json['Loss/G/loss']]
plt.plot(np.arange(0, len(topk_G_loss)/2, 0.5), topk_G_loss, label="Regular")
plt.legend()
plt.xlabel("kimg")
plt.ylabel("Loss")
plt.title("Generator Losses")
plt.show()

topk_D_loss = [d.get('mean') for d in topk_json['Loss/D/loss']]
plt.plot(np.arange(0, len(topk_D_loss)/2, 0.5), topk_D_loss, label="Top-K")
normal_D_loss = [d.get('mean') for d in normal_json['Loss/D/loss']]
plt.plot(np.arange(0, len(normal_D_loss)/2, 0.5), normal_D_loss, label="Regular")
plt.legend()
plt.xlabel("kimg")
plt.ylabel("Loss")
plt.title("Discriminator Losses")
plt.show()

# %%
topk_kid_jeep = pd.read_json(path_or_buf=topk_jeep_path+"metric-kid50k_full.jsonl", lines=True)
normal_kid_jeep = pd.read_json(path_or_buf=regular_jeep_path+"metric-kid50k_full.jsonl", lines=True)
topk_kid_fish = pd.read_json(path_or_buf=topk_fish_path+"metric-kid50k_full.jsonl", lines=True)
normal_kid_fish = pd.read_json(path_or_buf=regular_fish_path+"metric-kid50k_full.jsonl", lines=True)

# %%
topk_kid_mean = [d.get('kid50k_full')*1000 for d in topk_kid_jeep['results']]
plt.plot(np.arange(0, len(topk_kid_mean)), topk_kid_mean, label="Top-K Jeep")
normal_kid_mean = [d.get('kid50k_full')*1000 for d in normal_kid_jeep['results']]
plt.plot(np.arange(0, len(normal_kid_mean)), normal_kid_mean, label="Regular Jeep")
plt.xlabel("Evaluation Step")
plt.ylabel("KID")
plt.title("KID Scores for GANs")
plt.legend()
plt.show()

topk_kid_mean = [d.get('kid50k_full')*1000 for d in topk_kid_fish['results']]
plt.plot(np.arange(0, len(topk_kid_mean)), topk_kid_mean, label="Top-K Fish")
normal_kid_mean = [d.get('kid50k_full')*1000 for d in normal_kid_fish['results']]
plt.plot(np.arange(0, len(normal_kid_mean)), normal_kid_mean, label="Regular Fish")
plt.xlabel("Evaluation Step")
plt.ylabel("KID")
plt.title("KID Scores for GANs")
plt.legend()
plt.show()
